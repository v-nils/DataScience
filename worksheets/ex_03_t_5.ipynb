# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

import tensorflow as tf
from tensorflow.keras import layers, models, backend

import h5py
from scipy import ndimage

# block averaging for image degradation
def block_mean(ar, fact):
    assert isinstance(fact, int), type(fact)
    sx, sy = ar.shape
    X, Y = np.ogrid[0:sx, 0:sy]
    regions = sy//fact * (X//fact) + Y//fact
    res = ndimage.mean(ar, labels=regions, index=np.arange(regions.max() + 1))
    res.shape = (sx//fact, sy//fact)
    return res

# %% [markdown]
# # Read the dataset, normalise and scale

# %%
###########################################################
# load galaxy images from hdf5 file
ndown = 4
# use first 256 galaxies as training data
with h5py.File('data/raw_data/DECals_galaxies.hdf5', 'r') as F:
  images = np.array( F['images_spirals'] )
  # make grayscale
  images = np.mean(images, axis=-1)
  # downsample by 4
  imagesd = np.zeros((images.shape[0],images.shape[1]//ndown, images.shape[2]//ndown))
  for i in range( images.shape[0] ):
    imagesd[i,...] = block_mean( images[i,...], ndown )
  images = imagesd / 255

IMAGE_SIZE = images.shape[1]
CHANNELS   = 1
BATCH_SIZE = 128

###########################################################
# split into training and test data (first 32 galaxies are test data)
x_train = images[32:,:,:,None]
x_test  = images[:32,:,:,None]

###########################################################
# enable data augmentation, i.e. we randomly show the images flipped horizontally and vertically when training
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
])

###########################################################
#convert numpy arrays to tf.data.Dataset
train_dataset = tf.data.Dataset.from_tensor_slices((x_train,x_train)).batch( BATCH_SIZE )
aug_ds = train_dataset.map( lambda x, y: (data_augmentation(x, training=True), y))

test_dataset = tf.data.Dataset.from_tensor_slices((x_test,x_test)).batch( BATCH_SIZE )

# %% [markdown]
# # Define the encoder

# %%
# define hyperparameters
EMBEDDING_DIM = 4
EPOCHS = 400

# Encoder
encoder_input = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS), name="encoder_input")
x = layers.Conv2D(32, (3, 3), strides=2, activation="relu", padding="same")(encoder_input)
x = layers.Conv2D(64, (3, 3), strides=2, activation="relu", padding="same")(x)
x = layers.Conv2D(128, (3, 3), strides=2, activation="relu", padding="same")(x)
shape_before_flattening = backend.int_shape(x)[1:]  # the decoder will need this!
x = layers.Flatten()(x)
encoder_output = layers.Dense(EMBEDDING_DIM, name="encoder_output")(x)
encoder = models.Model(encoder_input, encoder_output)
encoder.summary()
# Out:
# Model: "functional_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder_input (InputLayer)      │ (None, 64, 64, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 32, 32, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_output (Dense)          │ (None, 4)              │        32,772 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 125,444 (490.02 KB)
#  Trainable params: 125,444 (490.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Define the decoder

# %%
# Decoder
decoder_input = layers.Input(shape=(EMBEDDING_DIM,), name="decoder_input")
x = layers.Dense(np.prod(shape_before_flattening))(decoder_input)
x = layers.Reshape(shape_before_flattening)(x)
x = layers.Conv2DTranspose( 128, (3, 3), strides=2, activation="relu", padding="same" )(x)
x = layers.Conv2DTranspose(  64, (3, 3), strides=2, activation="relu", padding="same" )(x)
x = layers.Conv2DTranspose(  32, (3, 3), strides=2, activation="relu", padding="same" )(x)
decoder_output = layers.Conv2D(CHANNELS, (3, 3), strides=1, activation="sigmoid", padding="same", name="decoder_output")(x)
decoder = models.Model(decoder_input, decoder_output)
decoder.summary()
# Out:
# Model: "functional_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ decoder_input (InputLayer)      │ (None, 4)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8192)           │        40,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 16, 16, 128)    │       147,584 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_4              │ (None, 32, 32, 64)     │        73,792 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_5              │ (None, 64, 64, 32)     │        18,464 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder_output (Conv2D)         │ (None, 64, 64, 1)      │           289 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 281,089 (1.07 MB)
#  Trainable params: 281,089 (1.07 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Assemble the autoencoder

# %%
# Autoencoder
autoencoder = models.Model( encoder_input, decoder(encoder_output) ) 
autoencoder.summary()

# Compile the autoencoder
autoencoder.compile(optimizer="adam", loss="mean_squared_error")
# Out:
# Model: "functional_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder_input (InputLayer)      │ (None, 64, 64, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 32, 32, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_output (Dense)          │ (None, 4)              │        32,772 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_12 (Functional)      │ (None, 64, 64, 1)      │       281,089 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params:
400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 292/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 270ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 293/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 294/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 295/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 296/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 297/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 298/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 241ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 299/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 300/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 301/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 254ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 302/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 303/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 304/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 245ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 305/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 306/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 240ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 307/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 308/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 309/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 272ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 310/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 268ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 311/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 262ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 312/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 313/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 314/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 270ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 315/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 246ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 316/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 317/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 253ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 318/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 319/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 320/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 321/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 253ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 322/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 323/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 324/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 325/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 326/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 327/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 328/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 329/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 270ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 330/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 331/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 310ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 332/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 295ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 333/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 282ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 334/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 261ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 335/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 235ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 336/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 337/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 338/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 244ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 339/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 340/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 341/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 342/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 343/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 270ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 344/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 270ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 345/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 346/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 279ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 347/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 348/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 240ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 349/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 350/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 249ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 351/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 352/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 353/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 354/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 355/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 356/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 357/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 358/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 246ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 359/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 360/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 245ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 361/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 362/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 363/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 364/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 365/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 366/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 367/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 252ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 368/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 278ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 369/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 287ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 370/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 371/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 279ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 372/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 280ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 373/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 277ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 374/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 335ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 375/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 356ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 376/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 324ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 377/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 279ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 378/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 270ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 379/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 380/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 381/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 291ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 382/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 257ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 383/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 257ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 384/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 252ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 385/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 254ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 386/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 387/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 388/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 277ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 389/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 272ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 390/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 301ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 391/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 271ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 392/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 290ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 393/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 394/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 278ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 395/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 396/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 280ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 397/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 398/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 288ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 399/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 400/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 269ms/step - loss: 0.0024 - val_loss: 0.0021

# %%
# Save the final models
autoencoder.save("./data/results/ex_03/models/autoencoder.keras")
encoder.save("./data/results/ex_03/models/encoder.keras")
decoder.save("./data/results/ex_03/models/decoder.keras")

# %%
n_to_predict = 5
example_images = x_test[:n_to_predict]
predictions = autoencoder.predict(example_images)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step

# %%
fig, ax = plt.subplots(2, n_to_predict, figsize=(8, 3))

plt.suptitle(f'latent space embedding dimensions: {EMBEDDING_DIM}')

for i in range(n_to_predict):
  ax[0, i].imshow(example_images[i, ...], cmap='viridis', vmin=0, vmax=1)
  ax[0, i].axis('off')
  ax[1, i].imshow(predictions[i, ...], cmap='viridis', vmin=0, vmax=1)
  ax[1, i].axis('off')
  
plt.subplots_adjust(wspace=0.1, hspace=0.1)
plt.savefig('./data/results/ex_03/autoencoder/autoencoder_results_dims_4.png')
# Out:
# <div id='5e2eaaef-4a58-4cda-ad90-4f41b157b3d3'></div>

# %%
import matplotlib.pyplot as plt
import scienceplots

plt.style.use(['science', 'ieee'])

# Pass the images through the encoder to get the latent space representations
latent_space_values = encoder.predict(x_test)

# Plot a histogram for each dimension of the latent space
for i in range(EMBEDDING_DIM):
    plt.figure(figsize=(6, 4))
    plt.hist(latent_space_values[:, i], bins=30)
    plt.xlim(-1.3, 3.1)
    plt.title(f'Latent space dimension {i+1}')
    plt.savefig(f'./data/results/ex_03/autoencoder/latent_space_histogram_{i+1}.png')

# Function to generate an image from a latent space vector
def generate_image(latent_vector, dim, value):
    # Set one of the dimensions to a specific value while setting all others to zero
    modified_vector = np.zeros_like(latent_vector)
    modified_vector[dim] = value

    # Pass the modified vector through the decoder to generate an image
    generated_image = decoder.predict(modified_vector[np.newaxis, :])

    return generated_image[0]

# Generate and show images for each dimension of the latent space
for i in range(EMBEDDING_DIM):
    plt.figure(figsize=(6, 4))
    generated_image = generate_image(latent_space_values[0], i, 1)
    plt.imshow(generated_image, cmap='viridis')
    plt.title(f'Generated image for dimension {i+1}')
    plt.savefig(f'./data/results/ex_03/autoencoder/generated_image_{i+1}.png')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# <div id='04a506cf-5af6-4d75-9470-be82362e088f'></div>
# <div id='68ba5ef9-ce4d-4658-a2f1-3300cb95f3d0'></div>
# <div id='619c972a-b97d-4f1f-94e0-8b9730c9583d'></div>
# <div id='7bbcfaf5-455b-4a29-a762-b8f5f1c946f3'></div>
# <div id='9d524cd1-9d58-48fe-a211-58e69d704c38'></div>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# <div id='aeb2be66-aaea-4f2d-adeb-51009286462b'></div>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# <div id='90b3d3a0-412f-4e75-8638-8916c559383a'></div>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# <div id='810d5557-081b-495d-be39-be0ac1514424'></div>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
